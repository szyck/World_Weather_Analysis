# %%
# Import Dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
from scipy.stats import linregress
from config1 import weather_api_key
from config1 import gkey

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=51469d2f30ddd178ed3b0e0d2722b107

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
cities
# Out:
# ['high rock',
#  'mys shmidta',
#  'point pedro',
#  'grand gaube',
#  'ushuaia',
#  'taolanaro',
#  'busselton',
#  'port alfred',
#  'vaini',
#  'bluff',
#  'honningsvag',
#  'sorland',
#  'victoria',
#  'isla vista',
#  'albany',
#  'raudeberg',
#  'hecun',
#  'nome',
#  'ngukurr',
#  'souillac',
#  'east london',
#  'touho',
#  'bajil',
#  'hasaki',
#  'powell river',
#  'atuona',
#  'rikitea',
#  'nizhneyansk',
#  'tiznit',
#  'payo',
#  'hobart',
#  'sao joao da barra',
#  'punta arenas',
#  'tasiilaq',
#  'mordovo',
#  'ahipara',
#  'iquique',
#  'lavrentiya',
#  'puerto ayora',
#  'esperance',
#  'boa vista',
#  'thompson',
#  'cadolzburg',
#  'jamestown',
#  'yellowknife',
#  'stokmarknes',
#  'lebu',
#  'khatanga',
#  'nabire',
#  'chapais',
#  'mar del plata',
#  'tilichiki',
#  'mtwara',
#  'new norfolk',
#  'mersing',
#  'roald',
#  'hilo',
#  'bambous virieux',
#  'saint-louis',
#  'zhigansk',
#  'attawapiskat',
#  'oranjemund',
#  'askarovo',
#  'paamiut',
#  'arraial do cabo',
#  'charters towers',
#  'vaitupu',
#  'port elizabeth',
#  'aljezur',
#  'constitucion',
#  'georgetown',
#  'egvekinot',
#  'butaritari',
#  'srednekolymsk',
#  'quelimane',
#  'illoqqortoormiut',
#  'obidos',
#  'tuktoyaktuk',
#  'chara',
#  'alyangula',
#  'katima mulilo',
#  'kinsale',
#  'airai',
#  'berlevag',
#  'kutum',
#  'moshkovo',
#  'kachiry',
#  'kapaa',
#  'sundargarh',
#  'castro',
#  'amga',
#  'plettenberg bay',
#  'tual',
#  'ilulissat',
#  'karaul',
#  'taltal',
#  'saint george',
#  'daru',
#  'coronado',
#  'broken hill',
#  'sompeta',
#  'pevek',
#  'fort nelson',
#  'osijek',
#  'avarua',
#  'faya',
#  'diu',
#  'klaksvik',
#  'krasnoselkup',
#  'kadykchan',
#  'likoporia',
#  'ancud',
#  'kaitangata',
#  'iskateley',
#  'verkhnyaya inta',
#  'luderitz',
#  'buta',
#  'bafq',
#  'bamiantong',
#  'bantou',
#  'caravelas',
#  'norman wells',
#  'shimoda',
#  'hermanus',
#  'mataura',
#  'road town',
#  'faanui',
#  'chokurdakh',
#  'ribeira grande',
#  'todos santos',
#  'okhotsk',
#  'saldanha',
#  'mbanza-ngungu',
#  'goderich',
#  'bubaque',
#  'mamlyutka',
#  'portland',
#  'tommot',
#  'labuan',
#  'san jose de sisa',
#  'kavieng',
#  'bacolod',
#  'acapulco',
#  'maarianhamina',
#  'shache',
#  'templin',
#  'saskylakh',
#  'hithadhoo',
#  'duz',
#  'dikson',
#  'stephenville',
#  'bredasdorp',
#  'itoman',
#  'trinidad',
#  'phan thiet',
#  'sataua',
#  'longyearbyen',
#  'lokoja',
#  'margate',
#  'barentsburg',
#  'katsuura',
#  'nautla',
#  'huarmey',
#  'nosy varika',
#  'nuuk',
#  'touros',
#  'atar',
#  'dubbo',
#  'bandarbeyla',
#  'barrow',
#  'eldikan',
#  'cayenne',
#  'husavik',
#  'tocache',
#  'severo-kurilsk',
#  'geraldton',
#  'amderma',
#  'torbay',
#  'port hardy',
#  'lohr',
#  'ouallam',
#  'temir',
#  'santa eulalia del rio',
#  'pleasanton',
#  'misratah',
#  'verkhnyaya toyma',
#  'inuvik',
#  'sinnamary',
#  'sitka',
#  'cherskiy',
#  'fortuna',
#  'alice springs',
#  'tuatapere',
#  'buarcos',
#  'chuy',
#  'axim',
#  'portales',
#  'qaanaaq',
#  'telimele',
#  'bethel',
#  'carnarvon',
#  'zhezkazgan',
#  'jerome',
#  'gold coast',
#  'bani',
#  'cabo san lucas',
#  'vardo',
#  'rocha',
#  'pecos',
#  'kodiak',
#  'qaqortoq',
#  'mikhaylovskoye',
#  'hermiston',
#  'belushya guba',
#  'najran',
#  'bandar-e lengeh',
#  'deputatskiy',
#  'korla',
#  'biltine',
#  'kharagpur',
#  'louisbourg',
#  'tecoanapa',
#  'quetzaltepec',
#  'hofn',
#  'ponta do sol',
#  'gravdal',
#  'viedma',
#  'jiazi',
#  'ambulu',
#  'kahului',
#  'bilma',
#  'port hedland',
#  'beringovskiy',
#  'clyde river',
#  'urumqi',
#  'karamea',
#  'tiksi',
#  'lata',
#  'fairmount',
#  'dinguiraye',
#  'nantucket',
#  'guardiagrele',
#  'nioro',
#  'champerico',
#  'kirksville',
#  'roebourne',
#  'tenenkou',
#  'mackay',
#  'saint-augustin',
#  'port-gentil',
#  'coahuayana',
#  'fecamp',
#  'amuntai',
#  'hoquiam',
#  'nikolskoye',
#  'praia da vitoria',
#  'skjaerhollen',
#  'rio grande',
#  'codrington',
#  'cape town',
#  'dunedin',
#  'san cristobal',
#  'victor harbor',
#  'montalto uffugo',
#  'toliary',
#  'calvinia',
#  'saleaula',
#  'dhidhdhoo',
#  'auce',
#  'akranes',
#  'upernavik',
#  'warrington',
#  'nampula',
#  'saint-francois',
#  'correntina',
#  'mahebourg',
#  'general roca',
#  'seoul',
#  'usinsk',
#  'necochea',
#  'svolvaer',
#  'rawson',
#  'atlantic city',
#  'bengkulu',
#  'auki',
#  'biak',
#  'westport',
#  'poronaysk',
#  'namibe',
#  'pasni',
#  'zlitan',
#  'djibo',
#  'vidim',
#  'haverfordwest',
#  'kaeo',
#  'ibra',
#  'lagunillas',
#  'isangel',
#  'lubben',
#  'hokitika',
#  'hvide sande',
#  'sao miguel do araguaia',
#  'horsham',
#  'qui nhon',
#  'tsihombe',
#  'houlung',
#  'olafsvik',
#  'grand bend',
#  'hakkari',
#  'samarai',
#  'abay',
#  'bilibino',
#  'hamilton',
#  'mogadishu',
#  'beloha',
#  'oleksandrivka',
#  'ajdabiya',
#  'upington',
#  'asosa',
#  'araouane',
#  'superior',
#  'eatonton',
#  'los llanos de aridane',
#  'lewiston',
#  'duluth',
#  'bonoua',
#  'saint-marc-des-carrieres',
#  'camacha',
#  'ucluelet',
#  'la baule-escoublac',
#  'santo antonio',
#  'vilya',
#  'riyadh',
#  'muros',
#  'bud',
#  'peterhead',
#  'pangnirtung',
#  'burica',
#  'noshiro',
#  'leningradskiy',
#  'manokwari',
#  'neiafu',
#  'valverde del camino',
#  'huancabamba',
#  'vanino',
#  'port blair',
#  'esso',
#  'college',
#  'iqaluit',
#  'ambon',
#  'birjand',
#  'ruatoria',
#  'mahibadhoo',
#  'iroquois falls',
#  'tumannyy',
#  'kyritz',
#  'broome',
#  'finschhafen',
#  'banda aceh',
#  'myaundzha',
#  'coquimbo',
#  'dali',
#  'sesheke',
#  'naze',
#  'grindavik',
#  'brownwood',
#  'khonuu',
#  'bur gabo',
#  'george',
#  'antalaha',
#  'pisco',
#  'soe',
#  'vila franca do campo',
#  'kirakira',
#  'inirida',
#  'mount isa',
#  'kushnarenkovo',
#  'zheshart',
#  'penzance',
#  'darnah',
#  'casma',
#  'lichinga',
#  'nazilli',
#  'vestmannaeyjar',
#  'halifax',
#  'tanshui',
#  'carros',
#  'forio',
#  'barbar',
#  'hay river',
#  'rio gallegos',
#  'aklavik',
#  'vanavara',
#  'sattahip',
#  'kurtamysh',
#  'yulara',
#  'marrakesh',
#  'namwala',
#  'noumea',
#  'port lincoln',
#  'coro',
#  'provideniya',
#  'guarapari',
#  'terrace',
#  'narsaq',
#  'comodoro rivadavia',
#  'ust-ishim',
#  'samusu',
#  'umm lajj',
#  'san patricio',
#  'tamandare',
#  'asau',
#  'rio cuarto',
#  'komsomolskiy',
#  'rundu',
#  'sur',
#  'ilobu',
#  'gboko',
#  'salalah',
#  'novosil',
#  'tacuarembo',
#  'tandalti',
#  'erdaojiang',
#  'maragogi',
#  'stoyba',
#  'takoradi',
#  'mawlaik',
#  'yichun',
#  'camana',
#  'kade',
#  'yook',
#  'olkhovatka',
#  'pemba',
#  'linchuan',
#  'massakory',
#  'san juan de colon',
#  'boyolangu',
#  'bac lieu',
#  'klyuchevsk',
#  'hami',
#  'tuggurt',
#  'mithimna',
#  'winnemucca',
#  'harrisonburg',
#  'carbonear',
#  'dolbeau',
#  'sioux lookout',
#  'ust-nera',
#  'cidreira',
#  'den helder',
#  'lima',
#  'samana',
#  'kitimat',
#  'kathmandu',
#  'hirara',
#  'lac du bonnet',
#  'kotli loharan',
#  'dusetos',
#  'kant',
#  'kunming',
#  'itarema',
#  'yumen',
#  'yizheng',
#  'port-cartier',
#  'saint-philippe',
#  'gigmoto',
#  'ha giang',
#  'vilyuysk',
#  'tiarei',
#  'saint-pierre',
#  'matara',
#  'kwekwe',
#  'qeshm',
#  'tsumeb',
#  'moindou',
#  'charlestown',
#  'karakose',
#  'esil',
#  'lolua',
#  'eisiskes',
#  'coihaique',
#  'udachnyy',
#  'narasannapeta',
#  'mount gambier',
#  'pak phanang',
#  'conakry',
#  'remicourt',
#  'nizwa',
#  'matagami',
#  'altamira',
#  'hammerfest',
#  'sao jose dos campos',
#  'rodos',
#  'raduzhnyy',
#  'raga',
#  'bonthe',
#  'alappuzha',
#  'borama',
#  'dhankuta',
#  'taburi',
#  'maniitsoq',
#  'lago da pedra',
#  'honiara',
#  'itupiranga',
#  'stolin',
#  'bhatapara',
#  'khorixas',
#  'homer',
#  'aktash',
#  'zyryanka',
#  'vao',
#  'padang',
#  'turukhansk',
#  'capreol',
#  'inongo',
#  'khandbari',
#  'spiridonovka',
#  'pangkalanbuun',
#  'davila',
#  'lompoc',
#  'tabiauea',
#  'havoysund',
#  'jinka',
#  'ixtapa',
#  'fomboni',
#  'lobito',
#  'peniche',
#  'meyungs',
#  'cordoba',
#  'kijang',
#  'te anau',
#  'smithers',
#  'totoral',
#  'tura',
#  'kiria',
#  'verishen',
#  'matay',
#  'kailua',
#  'huanan',
#  'buchanan',
#  'buin',
#  'naryan-mar',
#  'eyl',
#  'thio',
#  'espanola',
#  'bintulu',
#  'zaysan',
#  'havre-saint-pierre',
#  'blue springs',
#  'namtsy',
#  'vila velha',
#  'embonas',
#  'akyab',
#  'greenwood',
#  'palabuhanratu',
#  'coos bay',
#  'san lawrenz',
#  'mattru',
#  'gualaquiza',
#  'lazaro cardenas',
#  'dawlatabad',
#  'cap malheureux',
#  'innisfail',
#  'zambezi',
#  'stromness',
#  'ambodifototra',
#  'iberia',
#  'prince rupert',
#  'kegayli',
#  'skagastrond',
#  'ourem',
#  'japoata',
#  'pochutla',
#  'karratha',
#  'buraydah',
#  'bahir dar',
#  'brokopondo',
#  'aurora',
#  'danjiangkou',
#  'standerton',
#  'hobyo',
#  'werneck',
#  'ribeira brava',
#  'fort-shevchenko',
#  'kamenskoye',
#  'acajutla',
#  'minervino murge',
#  'salta',
#  'anamur',
#  'balkhash',
#  'tucuman',
#  'governador valadares',
#  'muisne',
#  'wukari',
#  'isla mujeres',
#  'kuching',
#  'lasa',
#  'luanda',
#  'tari',
#  'preeceville',
#  'quatre cocos',
#  'wanning',
#  'avera',
#  'kosh-agach',
#  'kamenka',
#  'santiago del estero',
#  'la ronge',
#  'paris',
#  'kuryk',
#  'do gonbadan',
#  'truth or consequences',
#  'talnakh',
#  'visby',
#  'sayyan',
#  'takhtamygda',
#  'atambua',
#  'skeldon',
#  'brahmapuri',
#  'ozgon',
#  'guantanamo',
#  'luebo',
#  'progreso',
#  'castle rock',
#  'shonguy',
#  'bathsheba',
#  'hovd',
#  'morondava',
#  'nishihara',
#  'baykit',
#  'wattegama',
#  'bondoukou',
#  'cockburn town',
#  'namie',
#  'aripuana',
#  'queanbeyan',
#  'cooma',
#  'coari',
#  'panguna',
#  'impfondo',
#  'evanston',
#  'healdsburg',
#  'merritt',
#  'kismayo',
#  'athenree',
#  'wajima',
#  'aleysk',
#  'saint-georges',
#  'los algarrobos',
#  'banes',
#  'tartagal',
#  'chilca',
#  'chagda',
#  'svetlyy',
#  'chipata',
#  'poum',
#  'crotone',
#  'bloomfield',
#  'taitung',
#  'hendek',
#  'cochabamba',
#  'marysville',
#  'mnogovershinnyy',
#  'amparafaravola',
#  'wolmaranstad',
#  'utiroa',
#  'shanghai',
#  'fare',
#  'longhua',
#  'seka',
#  'gobabis',
#  'kot addu',
#  'puerto baquerizo moreno',
#  'tornio',
#  'le port',
#  'kloulklubed',
#  'kerman',
#  'biggar',
#  'bom jardim',
#  'mbandaka',
#  'truckee',
#  'borba',
#  'lorengau',
#  'jalacingo',
#  'brest',
#  'yomitan',
#  'griffith',
#  'moose factory',
#  'batagay-alyta',
#  'iquitos',
#  'tawkar',
#  'olecko',
#  'qasigiannguit',
#  'glendive',
#  'kenai',
#  'maghama',
#  'slave lake',
#  'russell',
#  'imeni poliny osipenko',
#  'salinopolis',
#  'diamantino',
#  'alofi',
#  'morehead',
#  'kokuy',
#  'kuopio',
#  'umzimvubu',
#  'serenje',
#  'corinto',
#  'garden city',
#  'jutai',
#  'pauini',
#  'saurimo',
#  'panhala',
#  'limulunga',
#  'makakilo city',
#  'lamar',
#  'manbij',
#  'newala',
#  'hibbing',
#  'grand river south east',
#  'kytmanovo',
#  'sobolevo',
#  'kapuskasing',
#  'sisimiut',
#  'simeykyne',
#  'mayo',
#  'presidente medici',
#  'yeniseysk',
#  'yar-sale',
#  'de aar',
#  'katesh',
#  'anadyr',
#  'tawang',
#  'douglas',
#  'lubango']

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | high rock
# Processing Record 2 of Set 15 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 15 | point pedro
# Processing Record 4 of Set 15 | grand gaube
# Processing Record 5 of Set 15 | ushuaia
# Processing Record 6 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 15 | busselton
# Processing Record 8 of Set 15 | port alfred
# Processing Record 9 of Set 15 | vaini
# Processing Record 10 of Set 15 | bluff
# Processing Record 11 of Set 15 | honningsvag
# Processing Record 12 of Set 15 | sorland
# Processing Record 13 of Set 15 | victoria
# Processing Record 14 of Set 15 | isla vista
# Processing Record 15 of Set 15 | albany
# Processing Record 16 of Set 15 | raudeberg
# Processing Record 17 of Set 15 | hecun
# Processing Record 18 of Set 15 | nome
# Processing Record 19 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 15 | souillac
# Processing Record 21 of Set 15 | east london
# Processing Record 22 of Set 15 | touho
# Processing Record 23 of Set 15 | bajil
# Processing Record 24 of Set 15 | hasaki
# Processing Record 25 of Set 15 | powell river
# Processing Record 26 of Set 15 | atuona
# Processing Record 27 of Set 15 | rikitea
# Processing Record 28 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 15 | tiznit
# Processing Record 30 of Set 15 | payo
# Processing Record 31 of Set 15 | hobart
# Processing Record 32 of Set 15 | sao joao da barra
# Processing Record 33 of Set 15 | punta arenas
# Processing Record 34 of Set 15 | tasiilaq
# Processing Record 35 of Set 15 | mordovo
# Processing Record 36 of Set 15 | ahipara
# Processing Record 37 of Set 15 | iquique
# Processing Record 38 of Set 15 | lavrentiya
# Processing Record 39 of Set 15 | puerto ayora
# Processing Record 40 of Set 15 | esperance
# Processing Record 41 of Set 15 | boa vista
# Processing Record 42 of Set 15 | thompson
# Processing Record 43 of Set 15 | cadolzburg
# Processing Record 44 of Set 15 | jamestown
# Processing Record 45 of Set 15 | yellowknife
# Processing Record 46 of Set 15 | stokmarknes
# Processing Record 47 of Set 15 | lebu
# Processing Record 48 of Set 15 | khatanga
# Processing Record 49 of Set 15 | nabire
# Processing Record 50 of Set 15 | chapais
# Processing Record 1 of Set 16 | mar del plata
# Processing Record 2 of Set 16 | tilichiki
# Processing Record 3 of Set 16 | mtwara
# Processing Record 4 of Set 16 | new norfolk
# Processing Record 5 of Set 16 | mersing
# Processing Record 6 of Set 16 | roald
# Processing Record 7 of Set 16 | hilo
# Processing Record 8 of Set 16 | bambous virieux
# Processing Record 9 of Set 16 | saint-louis
# Processing Record 10 of Set 16 | zhigansk
# Processing Record 11 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 16 | oranjemund
# Processing Record 13 of Set 16 | askarovo
# Processing Record 14 of Set 16 | paamiut
# Processing Record 15 of Set 16 | arraial do cabo
# Processing Record 16 of Set 16 | charters towers
# Processing Record 17 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 16 | port elizabeth
# Processing Record 19 of Set 16 | aljezur
# Processing Record 20 of Set 16 | constitucion
# Processing Record 21 of Set 16 | georgetown
# Processing Record 22 of Set 16 | egvekinot
# Processing Record 23 of Set 16 | butaritari
# Processing Record 24 of Set 16 | srednekolymsk
# Processing Record 25 of Set 16 | quelimane
# Processing Record 26 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 16 | obidos
# Processing Record 28 of Set 16 | tuktoyaktuk
# Processing Record 29 of Set 16 | chara
# Processing Record 30 of Set 16 | alyangula
# Processing Record 31 of Set 16 | katima mulilo
# Processing Record 32 of Set 16 | kinsale
# Processing Record 33 of Set 16 | airai
# Processing Record 34 of Set 16 | berlevag
# Processing Record 35 of Set 16 | kutum
# Processing Record 36 of Set 16 | moshkovo
# Processing Record 37 of Set 16 | kachiry
# Processing Record 38 of Set 16 | kapaa
# Processing Record 39 of Set 16 | sundargarh
# Processing Record 40 of Set 16 | castro
# Processing Record 41 of Set 16 | amga
# Processing Record 42 of Set 16 | plettenberg bay
# Processing Record 43 of Set 16 | tual
# Processing Record 44 of Set 16 | ilulissat
# Processing Record 45 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 16 | taltal
# Processing Record 47 of Set 16 | saint george
# Processing Record 48 of Set 16 | daru
# Processing Record 49 of Set 16 | coronado
# Processing Record 50 of Set 16 | broken hill
# Processing Record 1 of Set 17 | sompeta
# Processing Record 2 of Set 17 | pevek
# Processing Record 3 of Set 17 | fort nelson
# Processing Record 4 of Set 17 | osijek
# Processing Record 5 of Set 17 | avarua
# Processing Record 6 of Set 17 | faya
# Processing Record 7 of Set 17 | diu
# Processing Record 8 of Set 17 | klaksvik
# Processing Record 9 of Set 17 | krasnoselkup
# Processing Record 10 of Set 17 | kadykchan
# City not found. Skipping...
# Processing Record 11 of Set 17 | likoporia
# City not found. Skipping...
# Processing Record 12 of Set 17 | ancud
# Processing Record 13 of Set 17 | kaitangata
# Processing Record 14 of Set 17 | iskateley
# Processing Record 15 of Set 17 | verkhnyaya inta
# City not found. Skipping...
# Processing Record 16 of Set 17 | luderitz
# City not found. Skipping...
# Processing Record 17 of Set 17 | buta
# Processing Record 18 of Set 17 | bafq
# Processing Record 19 of Set 17 | bamiantong
# Processing Record 20 of Set 17 | bantou
# Processing Record 21 of Set 17 | caravelas
# Processing Record 22 of Set 17 | norman wells
# Processing Record 23 of Set 17 | shimoda
# Processing Record 24 of Set 17 | hermanus
# Processing Record 25 of Set 17 | mataura
# Processing Record 26 of Set 17 | road town
# Processing Record 27 of Set 17 | faanui
# Processing Record 28 of Set 17 | chokurdakh
# Processing Record 29 of Set 17 | ribeira grande
# Processing Record 30 of Set 17 | todos santos
# Processing Record 31 of Set 17 | okhotsk
# Processing Record 32 of Set 17 | saldanha
# Processing Record 33 of Set 17 | mbanza-ngungu
# Processing Record 34 of Set 17 | goderich
# Processing Record 35 of Set 17 | bubaque
# Processing Record 36 of Set 17 | mamlyutka
# Processing Record 37 of Set 17 | portland
# Processing Record 38 of Set 17 | tommot
# Processing Record 39 of Set 17 | labuan
# Processing Record 40 of Set 17 | san jose de sisa
# Processing Record 41 of Set 17 | kavieng
# Processing Record 42 of Set 17 | bacolod
# Processing Record 43 of Set 17 | acapulco
# Processing Record 44 of Set 17 | maarianhamina
# Processing Record 45 of Set 17 | shache
# Processing Record 46 of Set 17 | templin
# Processing Record 47 of Set 17 | saskylakh
# Processing Record 48 of Set 17 | hithadhoo
# Processing Record 49 of Set 17 | duz
# City not found. Skipping...
# Processing Record 50 of Set 17 | dikson
# Processing Record 1 of Set 18 | stephenville
# Processing Record 2 of Set 18 | bredasdorp
# Processing Record 3 of Set 18 | itoman
# Processing Record 4 of Set 18 | trinidad
# Processing Record 5 of Set 18 | phan thiet
# Processing Record 6 of Set 18 | sataua
# City not found. Skipping...
# Processing Record 7 of Set 18 | longyearbyen
# Processing Record 8 of Set 18 | lokoja
# Processing Record 9 of Set 18 | margate
# Processing Record 10 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 18 | katsuura
# Processing Record 12 of Set 18 | nautla
# Processing Record 13 of Set 18 | huarmey
# Processing Record 14 of Set 18 | nosy varika
# Processing Record 15 of Set 18 | nuuk
# Processing Record 16 of Set 18 | touros
# Processing Record 17 of Set 18 | atar
# Processing Record 18 of Set 18 | dubbo
# Processing Record 19 of Set 18 | bandarbeyla
# Processing Record 20 of Set 18 | barrow
# Processing Record 21 of Set 18 | eldikan
# City not found. Skipping...
# Processing Record 22 of Set 18 | cayenne
# Processing Record 23 of Set 18 | husavik
# Processing Record 24 of Set 18 | tocache
# Processing Record 25 of Set 18 | severo-kurilsk
# Processing Record 26 of Set 18 | geraldton
# Processing Record 27 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 18 | torbay
# Processing Record 29 of Set 18 | port hardy
# Processing Record 30 of Set 18 | lohr
# Processing Record 31 of Set 18 | ouallam
# Processing Record 32 of Set 18 | temir
# Processing Record 33 of Set 18 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 34 of Set 18 | pleasanton
# Processing Record 35 of Set 18 | misratah
# Processing Record 36 of Set 18 | verkhnyaya toyma
# Processing Record 37 of Set 18 | inuvik
# Processing Record 38 of Set 18 | sinnamary
# Processing Record 39 of Set 18 | sitka
# Processing Record 40 of Set 18 | cherskiy
# Processing Record 41 of Set 18 | fortuna
# Processing Record 42 of Set 18 | alice springs
# Processing Record 43 of Set 18 | tuatapere
# Processing Record 44 of Set 18 | buarcos
# Processing Record 45 of Set 18 | chuy
# Processing Record 46 of Set 18 | axim
# Processing Record 47 of Set 18 | portales
# Processing Record 48 of Set 18 | qaanaaq
# Processing Record 49 of Set 18 | telimele
# Processing Record 50 of Set 18 | bethel
# Processing Record 1 of Set 19 | carnarvon
# Processing Record 2 of Set 19 | zhezkazgan
# Processing Record 3 of Set 19 | jerome
# Processing Record 4 of Set 19 | gold coast
# Processing Record 5 of Set 19 | bani
# Processing Record 6 of Set 19 | cabo san lucas
# Processing Record 7 of Set 19 | vardo
# Processing Record 8 of Set 19 | rocha
# Processing Record 9 of Set 19 | pecos
# Processing Record 10 of Set 19 | kodiak
# Processing Record 11 of Set 19 | qaqortoq
# Processing Record 12 of Set 19 | mikhaylovskoye
# Processing Record 13 of Set 19 | hermiston
# Processing Record 14 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 19 | najran
# Processing Record 16 of Set 19 | bandar-e lengeh
# Processing Record 17 of Set 19 | deputatskiy
# Processing Record 18 of Set 19 | korla
# Processing Record 19 of Set 19 | biltine
# Processing Record 20 of Set 19 | kharagpur
# Processing Record 21 of Set 19 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 19 | tecoanapa
# Processing Record 23 of Set 19 | quetzaltepec
# City not found. Skipping...
# Processing Record 24 of Set 19 | hofn
# Processing Record 25 of Set 19 | ponta do sol
# Processing Record 26 of Set 19 | gravdal
# Processing Record 27 of Set 19 | viedma
# Processing Record 28 of Set 19 | jiazi
# Processing Record 29 of Set 19 | ambulu
# Processing Record 30 of Set 19 | kahului
# Processing Record 31 of Set 19 | bilma
# Processing Record 32 of Set 19 | port hedland
# Processing Record 33 of Set 19 | beringovskiy
# Processing Record 34 of Set 19 | clyde river
# Processing Record 35 of Set 19 | urumqi
# Processing Record 36 of Set 19 | karamea
# City not found. Skipping...
# Processing Record 37 of Set 19 | tiksi
# Processing Record 38 of Set 19 | lata
# Processing Record 39 of Set 19 | fairmount
# Processing Record 40 of Set 19 | dinguiraye
# Processing Record 41 of Set 19 | nantucket
# Processing Record 42 of Set 19 | guardiagrele
# Processing Record 43 of Set 19 | nioro
# Processing Record 44 of Set 19 | champerico
# Processing Record 45 of Set 19 | kirksville
# Processing Record 46 of Set 19 | roebourne
# Processing Record 47 of Set 19 | tenenkou
# Processing Record 48 of Set 19 | mackay
# Processing Record 49 of Set 19 | saint-augustin
# Processing Record 50 of Set 19 | port-gentil
# Processing Record 1 of Set 20 | coahuayana
# Processing Record 2 of Set 20 | fecamp
# Processing Record 3 of Set 20 | amuntai
# Processing Record 4 of Set 20 | hoquiam
# Processing Record 5 of Set 20 | nikolskoye
# Processing Record 6 of Set 20 | praia da vitoria
# Processing Record 7 of Set 20 | skjaerhollen
# City not found. Skipping...
# Processing Record 8 of Set 20 | rio grande
# Processing Record 9 of Set 20 | codrington
# Processing Record 10 of Set 20 | cape town
# Processing Record 11 of Set 20 | dunedin
# Processing Record 12 of Set 20 | san cristobal
# Processing Record 13 of Set 20 | victor harbor
# Processing Record 14 of Set 20 | montalto uffugo
# Processing Record 15 of Set 20 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 20 | calvinia
# Processing Record 17 of Set 20 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 20 | dhidhdhoo
# Processing Record 19 of Set 20 | auce
# Processing Record 20 of Set 20 | akranes
# Processing Record 21 of Set 20 | upernavik
# Processing Record 22 of Set 20 | warrington
# Processing Record 23 of Set 20 | nampula
# Processing Record 24 of Set 20 | saint-francois
# Processing Record 25 of Set 20 | correntina
# Processing Record 26 of Set 20 | mahebourg
# Processing Record 27 of Set 20 | general roca
# Processing Record 28 of Set 20 | seoul
# Processing Record 29 of Set 20 | usinsk
# Processing Record 30 of Set 20 | necochea
# Processing Record 31 of Set 20 | svolvaer
# Processing Record 32 of Set 20 | rawson
# Processing Record 33 of Set 20 | atlantic city
# Processing Record 34 of Set 20 | bengkulu
# Processing Record 35 of Set 20 | auki
# Processing Record 36 of Set 20 | biak
# Processing Record 37 of Set 20 | westport
# Processing Record 38 of Set 20 | poronaysk
# Processing Record 39 of Set 20 | namibe
# Processing Record 40 of Set 20 | pasni
# Processing Record 41 of Set 20 | zlitan
# Processing Record 42 of Set 20 | djibo
# Processing Record 43 of Set 20 | vidim
# Processing Record 44 of Set 20 | haverfordwest
# Processing Record 45 of Set 20 | kaeo
# Processing Record 46 of Set 20 | ibra
# Processing Record 47 of Set 20 | lagunillas
# Processing Record 48 of Set 20 | isangel
# Processing Record 49 of Set 20 | lubben
# Processing Record 50 of Set 20 | hokitika
# Processing Record 1 of Set 21 | hvide sande
# Processing Record 2 of Set 21 | sao miguel do araguaia
# Processing Record 3 of Set 21 | horsham
# Processing Record 4 of Set 21 | qui nhon
# Processing Record 5 of Set 21 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 21 | houlung
# City not found. Skipping...
# Processing Record 7 of Set 21 | olafsvik
# Processing Record 8 of Set 21 | grand bend
# Processing Record 9 of Set 21 | hakkari
# Processing Record 10 of Set 21 | samarai
# Processing Record 11 of Set 21 | abay
# Processing Record 12 of Set 21 | bilibino
# Processing Record 13 of Set 21 | hamilton
# Processing Record 14 of Set 21 | mogadishu
# Processing Record 15 of Set 21 | beloha
# Processing Record 16 of Set 21 | oleksandrivka
# Processing Record 17 of Set 21 | ajdabiya
# Processing Record 18 of Set 21 | upington
# Processing Record 19 of Set 21 | asosa
# Processing Record 20 of Set 21 | araouane
# Processing Record 21 of Set 21 | superior
# Processing Record 22 of Set 21 | eatonton
# Processing Record 23 of Set 21 | los llanos de aridane
# Processing Record 24 of Set 21 | lewiston
# Processing Record 25 of Set 21 | duluth
# Processing Record 26 of Set 21 | bonoua
# Processing Record 27 of Set 21 | saint-marc-des-carrieres
# Processing Record 28 of Set 21 | camacha
# Processing Record 29 of Set 21 | ucluelet
# Processing Record 30 of Set 21 | la baule-escoublac
# Processing Record 31 of Set 21 | santo antonio
# Processing Record 32 of Set 21 | vilya
# Processing Record 33 of Set 21 | riyadh
# Processing Record 34 of Set 21 | muros
# Processing Record 35 of Set 21 | bud
# Processing Record 36 of Set 21 | peterhead
# Processing Record 37 of Set 21 | pangnirtung
# Processing Record 38 of Set 21 | burica
# City not found. Skipping...
# Processing Record 39 of Set 21 | noshiro
# Processing Record 40 of Set 21 | leningradskiy
# Processing Record 41 of Set 21 | manokwari
# Processing Record 42 of Set 21 | neiafu
# Processing Record 43 of Set 21 | valverde del camino
# Processing Record 44 of Set 21 | huancabamba
# Processing Record 45 of Set 21 | vanino
# Processing Record 46 of Set 21 | port blair
# Processing Record 47 of Set 21 | esso
# Processing Record 48 of Set 21 | college
# Processing Record 49 of Set 21 | iqaluit
# Processing Record 50 of Set 21 | ambon
# Processing Record 1 of Set 22 | birjand
# Processing Record 2 of Set 22 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 22 | mahibadhoo
# Processing Record 4 of Set 22 | iroquois falls
# Processing Record 5 of Set 22 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 22 | kyritz
# Processing Record 7 of Set 22 | broome
# Processing Record 8 of Set 22 | finschhafen
# Processing Record 9 of Set 22 | banda aceh
# Processing Record 10 of Set 22 | myaundzha
# Processing Record 11 of Set 22 | coquimbo
# Processing Record 12 of Set 22 | dali
# Processing Record 13 of Set 22 | sesheke
# Processing Record 14 of Set 22 | naze
# Processing Record 15 of Set 22 | grindavik
# Processing Record 16 of Set 22 | brownwood
# Processing Record 17 of Set 22 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 22 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 22 | george
# Processing Record 20 of Set 22 | antalaha
# Processing Record 21 of Set 22 | pisco
# Processing Record 22 of Set 22 | soe
# Processing Record 23 of Set 22 | vila franca do campo
# Processing Record 24 of Set 22 | kirakira
# Processing Record 25 of Set 22 | inirida
# Processing Record 26 of Set 22 | mount isa
# Processing Record 27 of Set 22 | kushnarenkovo
# Processing Record 28 of Set 22 | zheshart
# Processing Record 29 of Set 22 | penzance
# Processing Record 30 of Set 22 | darnah
# Processing Record 31 of Set 22 | casma
# Processing Record 32 of Set 22 | lichinga
# Processing Record 33 of Set 22 | nazilli
# Processing Record 34 of Set 22 | vestmannaeyjar
# Processing Record 35 of Set 22 | halifax
# Processing Record 36 of Set 22 | tanshui
# City not found. Skipping...
# Processing Record 37 of Set 22 | carros
# Processing Record 38 of Set 22 | forio
# Processing Record 39 of Set 22 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 22 | hay river
# Processing Record 41 of Set 22 | rio gallegos
# Processing Record 42 of Set 22 | aklavik
# Processing Record 43 of Set 22 | vanavara
# Processing Record 44 of Set 22 | sattahip
# Processing Record 45 of Set 22 | kurtamysh
# Processing Record 46 of Set 22 | yulara
# Processing Record 47 of Set 22 | marrakesh
# Processing Record 48 of Set 22 | namwala
# Processing Record 49 of Set 22 | noumea
# Processing Record 50 of Set 22 | port lincoln
# Processing Record 1 of Set 23 | coro
# Processing Record 2 of Set 23 | provideniya
# Processing Record 3 of Set 23 | guarapari
# Processing Record 4 of Set 23 | terrace
# Processing Record 5 of Set 23 | narsaq
# Processing Record 6 of Set 23 | comodoro rivadavia
# Processing Record 7 of Set 23 | ust-ishim
# Processing Record 8 of Set 23 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 23 | umm lajj
# Processing Record 10 of Set 23 | san patricio
# Processing Record 11 of Set 23 | tamandare
# Processing Record 12 of Set 23 | asau
# Processing Record 13 of Set 23 | rio cuarto
# Processing Record 14 of Set 23 | komsomolskiy
# Processing Record 15 of Set 23 | rundu
# Processing Record 16 of Set 23 | sur
# Processing Record 17 of Set 23 | ilobu
# Processing Record 18 of Set 23 | gboko
# Processing Record 19 of Set 23 | salalah
# Processing Record 20 of Set 23 | novosil
# Processing Record 21 of Set 23 | tacuarembo
# Processing Record 22 of Set 23 | tandalti
# Processing Record 23 of Set 23 | erdaojiang
# Processing Record 24 of Set 23 | maragogi
# Processing Record 25 of Set 23 | stoyba
# City not found. Skipping...
# Processing Record 26 of Set 23 | takoradi
# Processing Record 27 of Set 23 | mawlaik
# Processing Record 28 of Set 23 | yichun
# Processing Record 29 of Set 23 | camana
# Processing Record 30 of Set 23 | kade
# Processing Record 31 of Set 23 | yook
# Processing Record 32 of Set 23 | olkhovatka
# Processing Record 33 of Set 23 | pemba
# Processing Record 34 of Set 23 | linchuan
# City not found. Skipping...
# Processing Record 35 of Set 23 | massakory
# Processing Record 36 of Set 23 | san juan de colon
# Processing Record 37 of Set 23 | boyolangu
# Processing Record 38 of Set 23 | bac lieu
# Processing Record 39 of Set 23 | klyuchevsk
# Processing Record 40 of Set 23 | hami
# Processing Record 41 of Set 23 | tuggurt
# City not found. Skipping...
# Processing Record 42 of Set 23 | mithimna
# City not found. Skipping...
# Processing Record 43 of Set 23 | winnemucca
# Processing Record 44 of Set 23 | harrisonburg
# Processing Record 45 of Set 23 | carbonear
# Processing Record 46 of Set 23 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 23 | sioux lookout
# Processing Record 48 of Set 23 | ust-nera
# Processing Record 49 of Set 23 | cidreira
# Processing Record 50 of Set 23 | den helder
# Processing Record 1 of Set 24 | lima
# Processing Record 2 of Set 24 | samana
# Processing Record 3 of Set 24 | kitimat
# Processing Record 4 of Set 24 | kathmandu
# Processing Record 5 of Set 24 | hirara
# Processing Record 6 of Set 24 | lac du bonnet
# Processing Record 7 of Set 24 | kotli loharan
# Processing Record 8 of Set 24 | dusetos
# Processing Record 9 of Set 24 | kant
# Processing Record 10 of Set 24 | kunming
# Processing Record 11 of Set 24 | itarema
# Processing Record 12 of Set 24 | yumen
# Processing Record 13 of Set 24 | yizheng
# Processing Record 14 of Set 24 | port-cartier
# Processing Record 15 of Set 24 | saint-philippe
# Processing Record 16 of Set 24 | gigmoto
# Processing Record 17 of Set 24 | ha giang
# Processing Record 18 of Set 24 | vilyuysk
# Processing Record 19 of Set 24 | tiarei
# Processing Record 20 of Set 24 | saint-pierre
# Processing Record 21 of Set 24 | matara
# Processing Record 22 of Set 24 | kwekwe
# Processing Record 23 of Set 24 | qeshm
# Processing Record 24 of Set 24 | tsumeb
# Processing Record 25 of Set 24 | moindou
# Processing Record 26 of Set 24 | charlestown
# Processing Record 27 of Set 24 | karakose
# City not found. Skipping...
# Processing Record 28 of Set 24 | esil
# Processing Record 29 of Set 24 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 24 | eisiskes
# Processing Record 31 of Set 24 | coihaique
# Processing Record 32 of Set 24 | udachnyy
# Processing Record 33 of Set 24 | narasannapeta
# Processing Record 34 of Set 24 | mount gambier
# Processing Record 35 of Set 24 | pak phanang
# Processing Record 36 of Set 24 | conakry
# Processing Record 37 of Set 24 | remicourt
# Processing Record 38 of Set 24 | nizwa
# Processing Record 39 of Set 24 | matagami
# Processing Record 40 of Set 24 | altamira
# Processing Record 41 of Set 24 | hammerfest
# Processing Record 42 of Set 24 | sao jose dos campos
# Processing Record 43 of Set 24 | rodos
# Processing Record 44 of Set 24 | raduzhnyy
# Processing Record 45 of Set 24 | raga
# Processing Record 46 of Set 24 | bonthe
# Processing Record 47 of Set 24 | alappuzha
# Processing Record 48 of Set 24 | borama
# City not found. Skipping...
# Processing Record 49 of Set 24 | dhankuta
# Processing Record 50 of Set 24 | taburi
# City not found. Skipping...
# Processing Record 1 of Set 25 | maniitsoq
# Processing Record 2 of Set 25 | lago da pedra
# Processing Record 3 of Set 25 | honiara
# Processing Record 4 of Set 25 | itupiranga
# Processing Record 5 of Set 25 | stolin
# Processing Record 6 of Set 25 | bhatapara
# Processing Record 7 of Set 25 | khorixas
# Processing Record 8 of Set 25 | homer
# Processing Record 9 of Set 25 | aktash
# Processing Record 10 of Set 25 | zyryanka
# Processing Record 11 of Set 25 | vao
# Processing Record 12 of Set 25 | padang
# Processing Record 13 of Set 25 | turukhansk
# Processing Record 14 of Set 25 | capreol
# Processing Record 15 of Set 25 | inongo
# Processing Record 16 of Set 25 | khandbari
# Processing Record 17 of Set 25 | spiridonovka
# Processing Record 18 of Set 25 | pangkalanbuun
# Processing Record 19 of Set 25 | davila
# Processing Record 20 of Set 25 | lompoc
# Processing Record 21 of Set 25 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 25 | havoysund
# Processing Record 23 of Set 25 | jinka
# Processing Record 24 of Set 25 | ixtapa
# Processing Record 25 of Set 25 | fomboni
# Processing Record 26 of Set 25 | lobito
# Processing Record 27 of Set 25 | peniche
# Processing Record 28 of Set 25 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 25 | cordoba
# Processing Record 30 of Set 25 | kijang
# Processing Record 31 of Set 25 | te anau
# Processing Record 32 of Set 25 | smithers
# Processing Record 33 of Set 25 | totoral
# Processing Record 34 of Set 25 | tura
# Processing Record 35 of Set 25 | kiria
# Processing Record 36 of Set 25 | verishen
# Processing Record 37 of Set 25 | matay
# Processing Record 38 of Set 25 | kailua
# Processing Record 39 of Set 25 | huanan
# Processing Record 40 of Set 25 | buchanan
# Processing Record 41 of Set 25 | buin
# Processing Record 42 of Set 25 | naryan-mar
# Processing Record 43 of Set 25 | eyl
# Processing Record 44 of Set 25 | thio
# Processing Record 45 of Set 25 | espanola
# Processing Record 46 of Set 25 | bintulu
# Processing Record 47 of Set 25 | zaysan
# Processing Record 48 of Set 25 | havre-saint-pierre
# Processing Record 49 of Set 25 | blue springs
# Processing Record 50 of Set 25 | namtsy
# Processing Record 1 of Set 26 | vila velha
# Processing Record 2 of Set 26 | embonas
# Processing Record 3 of Set 26 | akyab
# Processing Record 4 of Set 26 | greenwood
# Processing Record 5 of Set 26 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 26 | coos bay
# Processing Record 7 of Set 26 | san lawrenz
# Processing Record 8 of Set 26 | mattru
# Processing Record 9 of Set 26 | gualaquiza
# Processing Record 10 of Set 26 | lazaro cardenas
# Processing Record 11 of Set 26 | dawlatabad
# Processing Record 12 of Set 26 | cap malheureux
# Processing Record 13 of Set 26 | innisfail
# Processing Record 14 of Set 26 | zambezi
# Processing Record 15 of Set 26 | stromness
# Processing Record 16 of Set 26 | ambodifototra
# City not found. Skipping...
# Processing Record 17 of Set 26 | iberia
# Processing Record 18 of Set 26 | prince rupert
# Processing Record 19 of Set 26 | kegayli
# City not found. Skipping...
# Processing Record 20 of Set 26 | skagastrond
# City not found. Skipping...
# Processing Record 21 of Set 26 | ourem
# Processing Record 22 of Set 26 | japoata
# Processing Record 23 of Set 26 | pochutla
# Processing Record 24 of Set 26 | karratha
# Processing Record 25 of Set 26 | buraydah
# Processing Record 26 of Set 26 | bahir dar
# Processing Record 27 of Set 26 | brokopondo
# Processing Record 28 of Set 26 | aurora
# Processing Record 29 of Set 26 | danjiangkou
# Processing Record 30 of Set 26 | standerton
# Processing Record 31 of Set 26 | hobyo
# Processing Record 32 of Set 26 | werneck
# Processing Record 33 of Set 26 | ribeira brava
# Processing Record 34 of Set 26 | fort-shevchenko
# Processing Record 35 of Set 26 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 26 | acajutla
# Processing Record 37 of Set 26 | minervino murge
# Processing Record 38 of Set 26 | salta
# Processing Record 39 of Set 26 | anamur
# Processing Record 40 of Set 26 | balkhash
# Processing Record 41 of Set 26 | tucuman
# Processing Record 42 of Set 26 | governador valadares
# Processing Record 43 of Set 26 | muisne
# Processing Record 44 of Set 26 | wukari
# Processing Record 45 of Set 26 | isla mujeres
# Processing Record 46 of Set 26 | kuching
# Processing Record 47 of Set 26 | lasa
# Processing Record 48 of Set 26 | luanda
# Processing Record 49 of Set 26 | tari
# Processing Record 50 of Set 26 | preeceville
# Processing Record 1 of Set 27 | quatre cocos
# Processing Record 2 of Set 27 | wanning
# Processing Record 3 of Set 27 | avera
# Processing Record 4 of Set 27 | kosh-agach
# Processing Record 5 of Set 27 | kamenka
# Processing Record 6 of Set 27 | santiago del estero
# Processing Record 7 of Set 27 | la ronge
# Processing Record 8 of Set 27 | paris
# Processing Record 9 of Set 27 | kuryk
# Processing Record 10 of Set 27 | do gonbadan
# Processing Record 11 of Set 27 | truth or consequences
# Processing Record 12 of Set 27 | talnakh
# Processing Record 13 of Set 27 | visby
# Processing Record 14 of Set 27 | sayyan
# Processing Record 15 of Set 27 | takhtamygda
# Processing Record 16 of Set 27 | atambua
# Processing Record 17 of Set 27 | skeldon
# Processing Record 18 of Set 27 | brahmapuri
# City not found. Skipping...
# Processing Record 19 of Set 27 | ozgon
# City not found. Skipping...
# Processing Record 20 of Set 27 | guantanamo
# Processing Record 21 of Set 27 | luebo
# Processing Record 22 of Set 27 | progreso
# Processing Record 23 of Set 27 | castle rock
# Processing Record 24 of Set 27 | shonguy
# Processing Record 25 of Set 27 | bathsheba
# Processing Record 26 of Set 27 | hovd
# Processing Record 27 of Set 27 | morondava
# Processing Record 28 of Set 27 | nishihara
# Processing Record 29 of Set 27 | baykit
# Processing Record 30 of Set 27 | wattegama
# Processing Record 31 of Set 27 | bondoukou
# Processing Record 32 of Set 27 | cockburn town
# Processing Record 33 of Set 27 | namie
# Processing Record 34 of Set 27 | aripuana
# Processing Record 35 of Set 27 | queanbeyan
# Processing Record 36 of Set 27 | cooma
# Processing Record 37 of Set 27 | coari
# Processing Record 38 of Set 27 | panguna
# Processing Record 39 of Set 27 | impfondo
# Processing Record 40 of Set 27 | evanston
# Processing Record 41 of Set 27 | healdsburg
# Processing Record 42 of Set 27 | merritt
# Processing Record 43 of Set 27 | kismayo
# Processing Record 44 of Set 27 | athenree
# Processing Record 45 of Set 27 | wajima
# Processing Record 46 of Set 27 | aleysk
# Processing Record 47 of Set 27 | saint-georges
# Processing Record 48 of Set 27 | los algarrobos
# Processing Record 49 of Set 27 | banes
# Processing Record 50 of Set 27 | tartagal
# Processing Record 1 of Set 28 | chilca
# Processing Record 2 of Set 28 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 28 | svetlyy
# Processing Record 4 of Set 28 | chipata
# Processing Record 5 of Set 28 | poum
# Processing Record 6 of Set 28 | crotone
# Processing Record 7 of Set 28 | bloomfield
# Processing Record 8 of Set 28 | taitung
# Processing Record 9 of Set 28 | hendek
# Processing Record 10 of Set 28 | cochabamba
# Processing Record 11 of Set 28 | marysville
# Processing Record 12 of Set 28 | mnogovershinnyy
# Processing Record 13 of Set 28 | amparafaravola
# Processing Record 14 of Set 28 | wolmaranstad
# City not found. Skipping...
# Processing Record 15 of Set 28 | utiroa
# City not found. Skipping...
# Processing Record 16 of Set 28 | shanghai
# Processing Record 17 of Set 28 | fare
# Processing Record 18 of Set 28 | longhua
# Processing Record 19 of Set 28 | seka
# Processing Record 20 of Set 28 | gobabis
# Processing Record 21 of Set 28 | kot addu
# Processing Record 22 of Set 28 | puerto baquerizo moreno
# Processing Record 23 of Set 28 | tornio
# Processing Record 24 of Set 28 | le port
# Processing Record 25 of Set 28 | kloulklubed
# Processing Record 26 of Set 28 | kerman
# Processing Record 27 of Set 28 | biggar
# Processing Record 28 of Set 28 | bom jardim
# Processing Record 29 of Set 28 | mbandaka
# Processing Record 30 of Set 28 | truckee
# Processing Record 31 of Set 28 | borba
# Processing Record 32 of Set 28 | lorengau
# Processing Record 33 of Set 28 | jalacingo
# Processing Record 34 of Set 28 | brest
# Processing Record 35 of Set 28 | yomitan
# City not found. Skipping...
# Processing Record 36 of Set 28 | griffith
# Processing Record 37 of Set 28 | moose factory
# Processing Record 38 of Set 28 | batagay-alyta
# Processing Record 39 of Set 28 | iquitos
# Processing Record 40 of Set 28 | tawkar
# City not found. Skipping...
# Processing Record 41 of Set 28 | olecko
# Processing Record 42 of Set 28 | qasigiannguit
# Processing Record 43 of Set 28 | glendive
# Processing Record 44 of Set 28 | kenai
# Processing Record 45 of Set 28 | maghama
# City not found. Skipping...
# Processing Record 46 of Set 28 | slave lake
# Processing Record 47 of Set 28 | russell
# Processing Record 48 of Set 28 | imeni poliny osipenko
# Processing Record 49 of Set 28 | salinopolis
# Processing Record 50 of Set 28 | diamantino
# Processing Record 1 of Set 29 | alofi
# Processing Record 2 of Set 29 | morehead
# Processing Record 3 of Set 29 | kokuy
# Processing Record 4 of Set 29 | kuopio
# Processing Record 5 of Set 29 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 29 | serenje
# Processing Record 7 of Set 29 | corinto
# Processing Record 8 of Set 29 | garden city
# Processing Record 9 of Set 29 | jutai
# Processing Record 10 of Set 29 | pauini
# Processing Record 11 of Set 29 | saurimo
# Processing Record 12 of Set 29 | panhala
# Processing Record 13 of Set 29 | limulunga
# Processing Record 14 of Set 29 | makakilo city
# Processing Record 15 of Set 29 | lamar
# Processing Record 16 of Set 29 | manbij
# Processing Record 17 of Set 29 | newala
# Processing Record 18 of Set 29 | hibbing
# Processing Record 19 of Set 29 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 29 | kytmanovo
# Processing Record 21 of Set 29 | sobolevo
# Processing Record 22 of Set 29 | kapuskasing
# Processing Record 23 of Set 29 | sisimiut
# Processing Record 24 of Set 29 | simeykyne
# Processing Record 25 of Set 29 | mayo
# Processing Record 26 of Set 29 | presidente medici
# Processing Record 27 of Set 29 | yeniseysk
# Processing Record 28 of Set 29 | yar-sale
# Processing Record 29 of Set 29 | de aar
# Processing Record 30 of Set 29 | katesh
# Processing Record 31 of Set 29 | anadyr
# Processing Record 32 of Set 29 | tawang
# Processing Record 33 of Set 29 | douglas
# Processing Record 34 of Set 29 | lubango
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    High Rock  26.6208  -78.2833     86.02        73          41        7.96
# 1  Point Pedro   9.8167   80.2333     81.81        82         100       18.03
# 2  Grand Gaube -20.0064   57.6608     73.80        68          88        8.99
# 3      Ushuaia -54.8000  -68.3000     42.46        87          40       19.57
# 4    Busselton -33.6500  115.3333     58.82        71         100        8.01
# 5  Port Alfred -33.5906   26.8910     75.16        40         100       13.56
# 6        Vaini -21.2000 -175.2000     73.56       100          20        4.61
# 7        Bluff -46.6000  168.3333     41.81        73         100       35.86
# 8  Honningsvag  70.9821   25.9704     42.55        81         100       11.50
# 9      Sorland  67.6670   12.6934     48.06        94         100       18.32
#
#   Country                 Date
# 0      BS  2022-06-13 18:51:34
# 1      LK  2022-06-13 18:51:34
# 2      MU  2022-06-13 18:51:35
# 3      AR  2022-06-13 18:49:41
# 4      AU  2022-06-13 18:51:35
# 5      ZA  2022-06-13 18:51:35
# 6      TO  2022-06-13 18:51:36
# 7      NZ  2022-06-13 18:51:36
# 8      NO  2022-06-13 18:51:36
# 9      NO  2022-06-13 18:51:37

# %%
# Create the output file (CSV).
output_data_file = "cities2.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
